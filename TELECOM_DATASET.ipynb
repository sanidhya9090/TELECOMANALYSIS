# %%
import pandas as pd
import matplotlib.pyplot as plt
from openpyxl import workbook
from openpyxl.chart import BarChart, Reference

# %% [markdown]
# #***TELECOM DATASET***

# %%
df = pd.read_csv("/content/drive/MyDrive/project/TELECOM_USER_DATASET1000.csv")
df
# Out:
#      customerID  User_ID  gender  Age Region  tenure  Column2  \
# 0    7590-VHVEG        1  Female   34   East     1.0      NaN
# 1    5575-GNVDE        2    Male   26  South    34.0      NaN
# 2    3668-QPYBK        3    Male   50  North     2.0      NaN
# 3    7795-CFOCW        4    Male   37   West    45.0      NaN
# 4    9237-HQITU        5  Female   30  South     2.0      NaN
# ..          ...      ...     ...  ...    ...     ...      ...
# 995  3842-IYKUE      996  Female   62  North    35.0      NaN
# 996  6641-XRPSU      997  Female   52   East    34.0      NaN
# 997  1374-DMZUI      998  Female   23  North     4.0      NaN
# 998  2545-LXYVJ      999    Male   36   East    72.0      NaN
# 999         NaN     1000     NaN   47  South     NaN      NaN
#
#         MultipleLines InternetService              PaymentMethod Plan_Type  \
# 0    No phone service             DSL           Electronic check   Prepaid
# 1                  No             DSL               Mailed check  Postpaid
# 2                  No             DSL               Mailed check   Prepaid
# 3    No phone service             DSL  Bank transfer (automatic)  Postpaid
# 4                  No     Fiber optic           Electronic check  Postpaid
# ..                ...             ...                        ...       ...
# 995               Yes     Fiber optic    Credit card (automatic)   Prepaid
# 996                No     Fiber optic    Credit card (automatic)  Postpaid
# 997               Yes     Fiber optic           Electronic check   Prepaid
# 998                No              No  Bank transfer (automatic)   Prepaid
# 999               NaN             NaN                        NaN  Postpaid
#
#      Data_Usage_GB  Call_Duration_Min  Monthly_Bill  MonthlyCharges  \
# 0            43.39                352        518.17           29.85
# 1            11.17                852       1084.72           56.95
# 2            18.34               1013       1449.22           53.85
# 3             3.89                118        281.89           42.30
# 4            38.28               1202        703.62           70.70
# ..             ...                ...           ...             ...
# 995          26.06                236        559.49           85.30
# 996          39.43                781        909.40           70.00
# 997          47.16               1263       1938.71           94.30
# 998          37.47               1461       1349.75           20.70
# 999          36.17                478       1172.35             NaN
#
#     TotalCharges  Network_Rating  Column3 Churn
# 0          29.85               4      NaN    No
# 1         1889.5               1      NaN    No
# 2         108.15               3      NaN   Yes
# 3        1840.75               4      NaN    No
# 4         151.65               1      NaN   Yes
# ..           ...             ...      ...   ...
# 995       2917.5               2      NaN   Yes
# 996       2416.1               4      NaN   Yes
# 997       424.45               1      NaN   Yes
# 998       1492.1               5      NaN    No
# 999          NaN               3      NaN   NaN
#
# [1000 rows x 19 columns]

# %%
df.head(10).plot(figsize=(15,6),kind="bar")
# Out:
# <Axes: >

# %%
df.head(50).plot(x= "tenure", y= "MonthlyCharges",kind='bar',figsize=(15,7))
# Out:
# <Axes: xlabel='tenure'>

# %%
df.describe()
# Out:
#            User_ID         Age      tenure  Column2  Data_Usage_GB  \
# count  1000.000000  1000.00000  999.000000      0.0    1000.000000
# mean    500.500000    41.39200   32.249249      NaN      25.693840
# std     288.819436    13.68143   24.837729      NaN      14.325168
# min       1.000000    18.00000    0.000000      NaN       0.510000
# 25%     250.750000    29.00000    8.000000      NaN      13.125000
# 50%     500.500000    42.00000   29.000000      NaN      26.525000
# 75%     750.250000    53.00000   56.000000      NaN      38.215000
# max    1000.000000    64.00000   72.000000      NaN      49.990000
#
#        Call_Duration_Min  Monthly_Bill  MonthlyCharges  Network_Rating  \
# count        1000.000000   1000.000000      999.000000     1000.000000
# mean          781.861000   1028.508070       66.479980        3.030000
# std           410.894656    552.897058       29.934448        1.418842
# min            52.000000    100.350000       18.950000        1.000000
# 25%           435.750000    547.382500       42.000000        2.000000
# 50%           787.500000   1009.190000       74.250000        3.000000
# 75%          1132.250000   1513.987500       90.050000        4.000000
# max          1499.000000   1995.480000      116.250000        5.000000
#
#        Column3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customerID         999 non-null    object
#  1   User_ID            1000 non-null   int64
#  2   gender             999 non-null    object
#  3   Age                1000 non-null   int64
#  4   Region             1000 non-null   object
#  5   tenure             999 non-null    float64
#  6   Column2            0 non-null      float64
#  7   MultipleLines      999 non-null    object
#  8   InternetService    999 non-null    object
#  9   PaymentMethod      999 non-null    object
#  10  Plan_Type          1000 non-null   object
#  11  Data_Usage_GB      1000 non-null   float64
#  12  Call_Duration_Min  1000 non-null   int64
#  13  Monthly_Bill       1000 non-null   float64
#  14  MonthlyCharges     999 non-null    float64
#  15  TotalCharges       999 non-null    object
#  16  Network_Rating     1000 non-null   int64
#  17  Column3            0 non-null      float64
#  18  Churn              999 non-null    object
# dtypes: float64(6), int64(4), object(9)
# memory usage: 148.6+ KB

# %%
df.isnull().sum()
# Out:
# customerID              1
# User_ID                 0
# gender                  1
# Age                     0
# Region                  0
# tenure                  1
# Column2              1000
# MultipleLines           1
# InternetService         1
# PaymentMethod           1
# Plan_Type               0
# Data_Usage_GB           0
# Call_Duration_Min       0
# Monthly_Bill            0
# MonthlyCharges          1
# TotalCharges            1
# Network_Rating          0
# Column3              1000
# Churn                   1
# dtype: int64

# %%
df.dropna()
df
# Out:
#      customerID  User_ID  gender  Age Region  tenure  Column2  \
# 0    7590-VHVEG        1  Female   34   East     1.0      NaN
# 1    5575-GNVDE        2    Male   26  South    34.0      NaN
# 2    3668-QPYBK        3    Male   50  North     2.0      NaN
# 3    7795-CFOCW        4    Male   37   West    45.0      NaN
# 4    9237-HQITU        5  Female   30  South     2.0      NaN
# ..          ...      ...     ...  ...    ...     ...      ...
# 995  3842-IYKUE      996  Female   62  North    35.0      NaN
# 996  6641-XRPSU      997  Female   52   East    34.0      NaN
# 997  1374-DMZUI      998  Female   23  North     4.0      NaN
# 998  2545-LXYVJ      999    Male   36   East    72.0      NaN
# 999         NaN     1000     NaN   47  South     NaN      NaN
#
#         MultipleLines InternetService              PaymentMethod Plan_Type  \
# 0    No phone service             DSL           Electronic check   Prepaid
# 1                  No             DSL               Mailed check  Postpaid
# 2                  No             DSL               Mailed check   Prepaid
# 3    No phone service             DSL  Bank transfer (automatic)  Postpaid
# 4                  No     Fiber optic           Electronic check  Postpaid
# ..                ...             ...                        ...       ...
# 995               Yes     Fiber optic    Credit card (automatic)   Prepaid
# 996                No     Fiber optic    Credit card (automatic)  Postpaid
# 997               Yes     Fiber optic           Electronic check   Prepaid
# 998                No              No  Bank transfer (automatic)   Prepaid
# 999               NaN             NaN                        NaN  Postpaid
#
#      Data_Usage_GB  Call_Duration_Min  Monthly_Bill  MonthlyCharges  \
# 0            43.39                352        518.17           29.85
# 1            11.17                852       1084.72           56.95
# 2            18.34               1013       1449.22           53.85
# 3             3.89                118        281.89           42.30
# 4            38.28               1202        703.62           70.70
# ..             ...                ...           ...             ...
# 995          26.06                236        559.49           85.30
# 996          39.43                781        909.40           70.00
# 997          47.16               1263       1938.71           94.30
# 998          37.47               1461       1349.75           20.70
# 999          36.17                478       1172.35             NaN
#
#     TotalCharges  Network_Rating  Column3 Churn
# 0          29.85               4      NaN    No
# 1         1889.5               1      NaN    No
# 2         108.15               3      NaN   Yes
# 3        1840.75               4      NaN    No
# 4         151.65               1      NaN   Yes
# ..           ...             ...      ...   ...
# 995       2917.5               2      NaN   Yes
# 996       2416.1               4      NaN   Yes
# 997       424.45               1      NaN   Yes
# 998       1492.1               5      NaN    No
# 999          NaN               3      NaN   NaN
#
# [1000 rows x 19 columns]

# %%
print("shape of data",df.shape)
df.head()
# Out:
# shape of data (1000, 19)
#    customerID  User_ID  gender  Age Region  tenure  Column2     MultipleLines  \
# 0  7590-VHVEG        1  Female   34   East     1.0      NaN  No phone service
# 1  5575-GNVDE        2    Male   26  South    34.0      NaN                No
# 2  3668-QPYBK        3    Male   50  North     2.0      NaN                No
# 3  7795-CFOCW        4    Male   37   West    45.0      NaN  No phone service
# 4  9237-HQITU        5  Female   30  South     2.0      NaN                No
#
#   InternetService              PaymentMethod Plan_Type  Data_Usage_GB  \
# 0             DSL           Electronic check   Prepaid          43.39
# 1             DSL               Mailed check  Postpaid          11.17
# 2             DSL               Mailed check   Prepaid          18.34
# 3             DSL  Bank transfer (automatic)  Postpaid           3.89
# 4     Fiber optic           Electronic check  Postpaid          38.28
#
#    Call_Duration_Min  Monthly_Bill  MonthlyCharges TotalCharges  \
# 0                352        518.17           29.85        29.85
# 1                852       1084.72           56.95       1889.5
# 2               1013       1449.22           53.85       108.15
# 3                118        281.89           42.30      1840.75
# 4               1202        703.62           70.70       151.65
#
#    Network_Rating  Column3 Churn
# 0               4      NaN    No
# 1               1      NaN    No
# 2               3      NaN   Yes
# 3               4      NaN    No
# 4               1      NaN   Yes

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
Filtered_data = df[(df['TotalCharges'] > 100) & (df['tenure'] == 50)]
Filtered_data
# Out:
#      customerID  User_ID  gender  Age Region  tenure  Column2 MultipleLines  \
# 68   3170-NMYVV       69  Female   56   East    50.0      NaN            No
# 231  3316-UWXUY      232    Male   43  South    50.0      NaN            No
# 257  6655-LHBYW      258    Male   37  South    50.0      NaN           Yes
# 266  6292-TOSSS      267    Male   32   West    50.0      NaN           Yes
# 548  4676-MQUEA      549    Male   50   East    50.0      NaN           Yes
# 614  7138-GIRSH      615    Male   61  South    50.0      NaN           Yes
# 647  2391-IPLOP      648    Male   53  North    50.0      NaN           Yes
# 830  9101-BWFSS      831  Female   27   West    50.0      NaN           Yes
# 891  3804-RVTGV      892    Male   20  North    50.0      NaN           Yes
# 899  2267-FPIMA      900    Male   21  South    50.0      NaN           Yes
#
#     InternetService              PaymentMethod Plan_Type  Data_Usage_GB  \
# 68               No  Bank transfer (automatic)  Postpaid          12.99
# 231     Fiber optic    Credit card (automatic)   Prepaid           5.71
# 257     Fiber optic    Credit card (automatic)  Postpaid           2.03
# 266              No  Bank transfer (automatic)  Postpaid          18.13
# 548     Fiber optic  Bank transfer (automatic)  Postpaid          35.65
# 614             DSL  Bank transfer (automatic)  Postpaid          11.35
# 647             DSL           Electronic check  Postpaid          25.98
# 830     Fiber optic           Electronic check  Postpaid           8.56
# 891     Fiber optic  Bank transfer (automatic)   Prepaid          22.81
# 899     Fiber optic    Credit card (automatic)  Postpaid          22.73
#
#      Call_Duration_Min  Monthly_Bill  MonthlyCharges  TotalCharges  \
# 68                 770        747.04           20.15        930.90
# 231                269        855.98           93.50       4747.50
# 257                444        719.06          114.35       5791.10
# 266                840       1645.53           24.90       1195.25
# 548               1416       1930.00          101.90       5265.50
# 614                269       1428.74           69.50       3418.20
# 647               1479        700.55           69.65       3442.15
# 830                136        880.35          108.55       5610.70
# 891                 79       1739.55          103.85       5017.90
# 899                655       1817.86           94.40       4914.90
#
#      Network_Rating  Column3 Churn
# 68                2      NaN    No
# 231               4      NaN    No
# 257               1      NaN    No
# 266               3      NaN    No
# 548               3      NaN    No
# 614               4      NaN    No
# 647               4      NaN    No
# 830               2      NaN   Yes
# 891               1      NaN   Yes
# 899               3      NaN    No

# %%
Filtered_data = df[(df['TotalCharges'] > 100) & (df['gender'] == 'Male')]
display(Filtered_data)
# Out:
#      customerID  User_ID gender  Age Region  tenure  Column2  \
# 1    5575-GNVDE        2   Male   26  South    34.0      NaN
# 2    3668-QPYBK        3   Male   50  North     2.0      NaN
# 3    7795-CFOCW        4   Male   37   West    45.0      NaN
# 6    1452-KIOVK        7   Male   46   West    22.0      NaN
# 9    6388-TABGU       10   Male   52  South    62.0      NaN
# ..          ...      ...    ...  ...    ...     ...      ...
# 981  1106-HRLKZ      982   Male   46  South    40.0      NaN
# 988  9046-JBFWA      989   Male   44  South    27.0      NaN
# 989  3280-NMUVX      990   Male   58  South    34.0      NaN
# 994  7277-KAMWT      995   Male   41  South    13.0      NaN
# 998  2545-LXYVJ      999   Male   36   East    72.0      NaN
#
#         MultipleLines InternetService              PaymentMethod Plan_Type  \
# 1                  No             DSL               Mailed check  Postpaid
# 2                  No             DSL               Mailed check   Prepaid
# 3    No phone service             DSL  Bank transfer (automatic)  Postpaid
# 6                 Yes     Fiber optic    Credit card (automatic)  Postpaid
# 9                  No             DSL  Bank transfer (automatic)   Prepaid
# ..                ...             ...                        ...       ...
# 981                No              No               Mailed check  Postpaid
# 988                No              No               Mailed check  Postpaid
# 989                No              No    Credit card (automatic)   Prepaid
# 994                No              No    Credit card (automatic)   Prepaid
# 998                No              No  Bank transfer (automatic)   Prepaid
#
#      Data_Usage_GB  Call_Duration_Min  Monthly_Bill  MonthlyCharges  \
# 1            11.17                852       1084.72           56.95
# 2            18.34               1013       1449.22           53.85
# 3             3.89                118        281.89           42.30
# 6            38.08                189        598.45           89.10
# 9            40.47                795        195.41           56.15
# ..             ...                ...           ...             ...
# 981          39.36               1400        955.54           19.60
# 988          10.90               1214       1167.54           19.15
# 989          14.41                875       1375.67           19.60
# 994           6.04                857       1148.68           20.00
# 998          37.47               1461       1349.75           20.70
#
#      TotalCharges  Network_Rating  Column3 Churn
# 1         1889.50               1      NaN    No
# 2          108.15               3      NaN   Yes
# 3         1840.75               4      NaN    No
# 6         1949.40               2      NaN    No
# 9         3487.95               4      NaN    No
# ..            ...             ...      ...   ...
# 981        808.95               5      NaN    No
# 988        537.35               2      NaN    No
# 989        678.80               1      NaN    No
# 994        268.45               2      NaN    No
# 998       1492.10               5      NaN    No
#
# [435 rows x 19 columns]

# %%
Filtered_data = df[(df['TotalCharges'] < 1000) & (df['gender'] == 'Female')]
display(Filtered_data)
# Out:
#      customerID  User_ID  gender  Age Region  tenure  Column2  \
# 0    7590-VHVEG        1  Female   34   East     1.0      NaN
# 4    9237-HQITU        5  Female   30  South     2.0      NaN
# 5    9305-CDSKC        6  Female   45   East     8.0      NaN
# 7    6713-OKOMC        8  Female   30   West    10.0      NaN
# 18   4190-MFLUW       19  Female   62   West    10.0      NaN
# ..          ...      ...     ...  ...    ...     ...      ...
# 980  3318-ISQFQ      981  Female   30  South    20.0      NaN
# 986  2604-XVDAM      987  Female   30  South    12.0      NaN
# 992  4883-KCPZJ      993  Female   48   East    22.0      NaN
# 993  9108-EQPNQ      994  Female   51   West    10.0      NaN
# 997  1374-DMZUI      998  Female   23  North     4.0      NaN
#
#         MultipleLines InternetService              PaymentMethod Plan_Type  \
# 0    No phone service             DSL           Electronic check   Prepaid
# 4                  No     Fiber optic           Electronic check  Postpaid
# 5                 Yes     Fiber optic           Electronic check  Postpaid
# 7    No phone service             DSL               Mailed check  Postpaid
# 18                 No             DSL    Credit card (automatic)   Prepaid
# ..                ...             ...                        ...       ...
# 980                No              No  Bank transfer (automatic)  Postpaid
# 986                No             DSL  Bank transfer (automatic)   Prepaid
# 992               Yes              No    Credit card (automatic)   Prepaid
# 993               Yes              No    Credit card (automatic)  Postpaid
# 997               Yes     Fiber optic           Electronic check   Prepaid
#
#      Data_Usage_GB  Call_Duration_Min  Monthly_Bill  MonthlyCharges  \
# 0            43.39                352        518.17           29.85
# 4            38.28               1202        703.62           70.70
# 5            20.71                245       1940.48           99.65
# 7            45.23                332        694.80           29.75
# 18           11.72               1462        856.63           55.20
# ..             ...                ...           ...             ...
# 980          25.25                194       1303.20           19.50
# 986          23.74                849       1855.74           43.80
# 992          20.73                929       1667.13           25.25
# 993          46.24                512       1408.74           26.10
# 997          47.16               1263       1938.71           94.30
#
#      TotalCharges  Network_Rating  Column3 Churn
# 0           29.85               4      NaN    No
# 4          151.65               1      NaN   Yes
# 5          820.50               3      NaN   Yes
# 7          301.90               2      NaN    No
# 18         528.35               1      NaN   Yes
# ..            ...             ...      ...   ...
# 980        413.00               5      NaN    No
# 986        540.95               3      NaN    No
# 992        555.40               3      NaN    No
# 993        225.55               1      NaN    No
# 997        424.45               1      NaN   Yes
#
# [205 rows x 19 columns]

# %%
df['Data_Usage_GB'].hist(bins=20)
plt.title('Data Usage Distribution')
plt.xlabel('Data Usage (GB)')
plt.ylabel('Number of Users')
plt.show()

# %%
df['Plan_Type'].value_counts().plot(kind='bar')
plt.title('Number of Users by Plan Type')
plt.show()

# %%
df.groupby('Region')['Monthly_Bill'].mean().plot(kind='bar')
plt.title('Average Monthly Bill by Region')
plt.ylabel('Average Bill (₹)')
plt.show()

# %%
pivot_table = pd.pivot_table(df, values='TotalCharges', index='Region', aggfunc='sum')
pivot_table
# Out:
#         TotalCharges
# Region
# East        484288.8
# North       561794.6
# South       680529.6
# West        605303.0

# %%
pivot_table = pd.pivot_table(df, values='Data_Usage_GB', index='Region', aggfunc='sum')
pivot_table
# Out:
#         Data_Usage_GB
# Region
# East          6089.25
# North         6693.37
# South         6662.50
# West          6248.72

# %%
churn_rate = df['Churn'].value_counts(normalize=True) * 100
print("Churn Rate (%):\n", churn_rate)
# Out:
# Churn Rate (%):
#  Churn
# No     74.374374
# Yes    25.625626
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6,4))
df['Data_Usage_GB'].hist(bins=25, color='blue')
plt.title('Distribution of Data Usage')
plt.xlabel('Data Usage (GB)')
plt.ylabel('Number of Users')
plt.show()

# %%
plt.figure(figsize=(6,4))
df.groupby('Region')['Monthly_Bill'].mean().plot(kind='bar', color='lightgreen')
plt.title('Average Monthly Bill by Region')
plt.ylabel('Average Bill (₹)')
plt.show()

# %%
plt.figure(figsize=(5,4))
df['Plan_Type'].value_counts().plot(kind='bar', color=['skyblue','orange'])
plt.title('Users by Plan Type')
plt.xlabel('Plan Type')
plt.ylabel('Count')
plt.show()

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df
# Out:
# /tmp/ipython-input-2368695939.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)
#      customerID  User_ID  gender  Age Region  tenure  Column2  \
# 0    7590-VHVEG        1  Female   34   East     1.0      NaN
# 1    5575-GNVDE        2    Male   26  South    34.0      NaN
# 2    3668-QPYBK        3    Male   50  North     2.0      NaN
# 3    7795-CFOCW        4    Male   37   West    45.0      NaN
# 4    9237-HQITU        5  Female   30  South     2.0      NaN
# ..          ...      ...     ...  ...    ...     ...      ...
# 995  3842-IYKUE      996  Female   62  North    35.0      NaN
# 996  6641-XRPSU      997  Female   52   East    34.0      NaN
# 997  1374-DMZUI      998  Female   23  North     4.0      NaN
# 998  2545-LXYVJ      999    Male   36   East    72.0      NaN
# 999         NaN     1000     NaN   47  South     NaN      NaN
#
#         MultipleLines InternetService              PaymentMethod Plan_Type  \
# 0    No phone service             DSL           Electronic check   Prepaid
# 1                  No             DSL               Mailed check  Postpaid
# 2                  No             DSL               Mailed check   Prepaid
# 3    No phone service             DSL  Bank transfer (automatic)  Postpaid
# 4                  No     Fiber optic           Electronic check  Postpaid
# ..                ...             ...                        ...       ...
# 995               Yes     Fiber optic    Credit card (automatic)   Prepaid
# 996                No     Fiber optic    Credit card (automatic)  Postpaid
# 997               Yes     Fiber optic           Electronic check   Prepaid
# 998                No              No  Bank transfer (automatic)   Prepaid
# 999               NaN             NaN                        NaN  Postpaid
#
#      Data_Usage_GB  Call_Duration_Min  Monthly_Bill  MonthlyCharges  \
# 0            43.39                352        518.17           29.85
# 1            11.17                852       1084.72           56.95
# 2            18.34               1013       1449.22           53.85
# 3             3.89                118        281.89           42.30
# 4            38.28               1202        703.62           70.70
# ..             ...                ...           ...             ...
# 995          26.06                236        559.49           85.30
# 996          39.43                781        909.40           70.00
# 997          47.16               1263       1938.71           94.30
# 998          37.47               1461       1349.75           20.70
# 999          36.17                478       1172.35             NaN
#
#      TotalCharges  Network_Rating  Column3 Churn
# 0           29.85               4      NaN    No
# 1         1889.50               1      NaN    No
# 2          108.15               3      NaN   Yes
# 3         1840.75               4      NaN    No
# 4          151.65               1      NaN   Yes
# ..            ...             ...      ...   ...
# 995       2917.50               2      NaN   Yes
# 996       2416.10               4      NaN   Yes
# 997        424.45               1      NaN   Yes
# 998       1492.10               5      NaN    No
# 999           NaN               3      NaN   NaN
#
# [1000 rows x 19 columns]

# %%
mean = df.mean(numeric_only=True)
mean
# Out:
# User_ID               500.50000
# Age                    41.39200
# tenure                 32.21700
# Column2                 0.00000
# Data_Usage_GB          25.69384
# Call_Duration_Min     781.86100
# Monthly_Bill         1028.50807
# MonthlyCharges         66.41350
# TotalCharges         2331.91600
# Network_Rating          3.03000
# Column3                 0.00000
# dtype: float64

# %%
median = df.median(numeric_only=True)
median
# Out:
# User_ID               500.500
# Age                    42.000
# tenure                 29.000
# Column2                 0.000
# Data_Usage_GB          26.525
# Call_Duration_Min     787.500
# Monthly_Bill         1009.190
# MonthlyCharges         74.250
# TotalCharges         1448.875
# Network_Rating          3.000
# Column3                 0.000
# dtype: float64

# %%
plan_type_counts = df['Plan_Type'].value_counts()
plt.figure(figsize=(7, 7))
plt.pie(plan_type_counts, labels=plan_type_counts.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'orange'])
plt.title('Distribution of Users by Plan Type')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['tenure'], df['TotalCharges'], alpha=0.5)
plt.xlabel('Tenure (Months)')
plt.ylabel('Total Charges')
plt.title('Total Charges vs. Tenure')
plt.grid(True)
plt.show()

# %% [markdown]
# You can link your GitHub account with Colab to save your notebooks directly to GitHub, load notebooks from GitHub, and share your work.
#
# Here's how to link your GitHub account:
#
# 1.  Go to **File** > **Save a copy to GitHub**.
# 2.  This will open a dialog box asking you to authorize Colab to access your GitHub repositories.
# 3.  Click on **Authorize GoogleColab**.
# 4.  You will be redirected to GitHub to complete the authorization process.
#
# Once linked, you can use **File** > **Load from GitHub** to open notebooks stored in your repositories.

# %%
import openpyxl
from openpyxl import workbook
from openpyxl.chart import BarChart, Reference

Wb = openpyxl.Workbook()
Ws = Wb.active
Ws.title = "Revenue by Product"
print(df.columns)
Wb.save("Revenue_by_product.xlsx")
# Out:
# Index(['customerID', 'User_ID', 'gender', 'Age', 'Region', 'tenure', 'Column2',
#        'MultipleLines', 'InternetService', 'PaymentMethod', 'Plan_Type',
#        'Data_Usage_GB', 'Call_Duration_Min', 'Monthly_Bill', 'MonthlyCharges',
#        'TotalCharges', 'Network_Rating', 'Column3', 'Churn'],
#       dtype='object')
